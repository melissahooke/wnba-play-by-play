# %%
import requests
import json
import pandas as pd
import re
from datetime import datetime

# %%
year = '2016'
game_type = '2' #game_type = 1:preseason; 2:regular season; 3:all-star; 4:playoff
game_num = '001' #game_num = 1-n for preseason/regular season; series+0+number(1-5)
quarter_num = '1'
gid = '10'+game_type+year[2:4]+'00'+game_num
quarter_num = '1'
game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
r = requests.get(game_url)
game_data = json.loads(r.text)

# %%
def save_new_rows(df,game_data,game_season):
    game_info = game_data['gcode']
    newRows = pandas.DataFrame.from_dict(game_data['pla'])
    game_info = re.split('/',game_info)
    newRows['gid'] = gid
    newRows['year'] = year
    newRows['gameType'] = game_season
    newRows['quarter'] = int(quarter_num)
    newRows['date'] = datetime.strptime(game_info[0],'%Y%m%d')
    newRows['homeTeam'] = game_info[1][3:6]
    newRows['awayTeam'] = game_info[1][0:3]
    df = df.append(newRows)
    return df

# %%
game_data
# Out:
# {'g': {'mid': 1463271894863,
#   'gid': '1021600001',
#   'gcode': '20160514/DALIND',
#   'p': 1,
#   'next': 'http://data.wnba.com/data/v2015/json/mobile_teams/wnba/2016/scores/pbp/1021600001_1_pbp.json',
#   'pla': [{'evt': 0,
#     'cl': '10:00',
#     'de': 'Start Period',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 12,
#     'opid': '',
#     'tid': 0,
#     'pid': 0,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 0},
#    {'evt': 1,
#     'cl': '10:00',
#     'de': 'Jump Ball Larkins vs Paris (Christmas gains possession)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 10,
#     'opid': '201907',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 0,
#     'vs': 0,
#     'epid': '202640',
#     'oftid': 1611661321},
#    {'evt': 2,
#     'cl': '09:46',
#     'de': '[DAL] Paris Turnover : Lost Ball (1 TO) Steal:Larkins (1 ST)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 2,
#     'etype': 5,
#     'opid': '201503',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 3,
#     'cl': '09:38',
#     'de': '[IND] Wheeler Turnover : Out of Bounds - Bad Pass Turnover (1 TO)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 45,
#     'etype': 5,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 4,
#     'cl': '09:26',
#     'de': '[DAL] Christmas 3pt Shot: Missed',
#     'locX': -240,
#     'locY': -6,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 202640,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 5,
#     'cl': '09:25',
#     'de': '[IND] Larkins Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 6,
#     'cl': '09:20',
#     'de': '[DAL] Paris Foul: Shooting (1 PF) (2 FTA)',
#     'locX': 29,
#     'locY': -10,
#     'opt1': 0,
#     'opt2': 1,
#     'mtype': 2,
#     'etype': 6,
#     'opid': '100646',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 0,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 7,
#     'cl': '09:20',
#     'de': '[IND 1-0] Catchings Free Throw 1 of 2 (1 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 1,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 1,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 9,
#     'cl': '09:20',
#     'de': '[IND 2-0] Catchings Free Throw 2 of 2 (2 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 1,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 2,
#     'vs': 0,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 11,
#     'cl': '08:58',
#     'de': '[DAL 3-2] Phillips 3pt Shot: Made (3 PTS) Assist: Sims (1 AST)',
#     'locX': 233,
#     'locY': -11,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 101039,
#     'hs': 2,
#     'vs': 3,
#     'epid': '203824',
#     'oftid': 1611661321},
#    {'evt': 12,
#     'cl': '08:37',
#     'de': '[IND 4-3] Wheeler Pullup Jump shot: Made (2 PTS) Assist: Larkins (1 AST)',
#     'locX': 20,
#     'locY': 151,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 79,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 4,
#     'vs': 3,
#     'epid': '201503',
#     'oftid': 1611661325},
#    {'evt': 13,
#     'cl': '08:22',
#     'de': '[DAL] Paris Jump Shot: Missed Block: Catchings (1 BLK)',
#     'locX': -29,
#     'locY': 25,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '100646',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 4,
#     'vs': 3,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 14,
#     'cl': '08:22',
#     'de': '[DAL] Paris Rebound (Off:1 Def:0)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 4,
#     'vs': 3,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 15,
#     'cl': '08:22',
#     'de': 'Jump Ball Catchings vs Paris (Phillips gains possession)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 10,
#     'opid': '201907',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 4,
#     'vs': 3,
#     'epid': '101039',
#     'oftid': 1611661321},
#    {'evt': 16,
#     'cl': '08:09',
#     'de': '[DAL 5-4] Pierson Step Back Jump shot: Made (2 PTS)',
#     'locX': 118,
#     'locY': 75,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 80,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 4,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 17,
#     'cl': '07:55',
#     'de': '[IND] Mitchell Jump Shot: Missed',
#     'locX': 84,
#     'locY': 138,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 4,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 18,
#     'cl': '07:54',
#     'de': '[IND] Larkins Rebound (Off:1 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 4,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 19,
#     'cl': '07:53',
#     'de': '[DAL] Paris Foul: Shooting (2 PF) (2 FTA)',
#     'locX': 13,
#     'locY': -5,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 2,
#     'etype': 6,
#     'opid': '201503',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 4,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 20,
#     'cl': '07:53',
#     'de': '[IND 5-5] Larkins Free Throw 1 of 2 (1 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 5,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 22,
#     'cl': '07:53',
#     'de': '[IND 6-5] Larkins Free Throw 2 of 2 (2 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 24,
#     'cl': '07:36',
#     'de': '[IND] Catchings Foul: Personal (1 PF)',
#     'locX': -133,
#     'locY': 192,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '101039',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 25,
#     'cl': '07:31',
#     'de': '[DAL] Pierson Jump Shot: Missed',
#     'locX': -95,
#     'locY': 194,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 26,
#     'cl': '07:30',
#     'de': '[IND] Johnson Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203018,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 27,
#     'cl': '07:25',
#     'de': '[DAL] Sims Foul: Personal (1 PF)',
#     'locX': 127,
#     'locY': 189,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '100646',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 28,
#     'cl': '07:15',
#     'de': '[IND] Wheeler Driving Layup Shot: Missed',
#     'locX': 18,
#     'locY': 11,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 42,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 29,
#     'cl': '07:14',
#     'de': '[DAL] Paris Rebound (Off:1 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 30,
#     'cl': '07:06',
#     'de': '[DAL] Phillips Turnover : Bad Pass (1 TO) Steal:Johnson (1 ST)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 5,
#     'opid': '203018',
#     'tid': 1611661321,
#     'pid': 101039,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 31,
#     'cl': '07:00',
#     'de': '[IND] Catchings 3pt Shot: Missed',
#     'locX': 173,
#     'locY': 195,
#     'opt1': 3,
#     'opt2': 1,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 32,
#     'cl': '06:59',
#     'de': '[IND] Mitchell Rebound (Off:1 Def:0)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 33,
#     'cl': '06:46',
#     'de': '[IND] Johnson Jump Shot: Missed',
#     'locX': -106,
#     'locY': 149,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203018,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 34,
#     'cl': '06:45',
#     'de': '[DAL] Christmas Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 202640,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 35,
#     'cl': '06:24',
#     'de': '[DAL] Pierson Jump Shot: Missed',
#     'locX': -79,
#     'locY': 189,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 36,
#     'cl': '06:23',
#     'de': '[IND] Johnson Rebound (Off:0 Def:2)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203018,
#     'hs': 6,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 37,
#     'cl': '06:17',
#     'de': '[IND 8-5] Catchings Cutting Layup Shot: Made (4 PTS) Assist: Johnson (1 AST)',
#     'locX': 21,
#     'locY': 3,
#     'opt1': 2,
#     'opt2': 1,
#     'mtype': 98,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 8,
#     'vs': 5,
#     'epid': '203018',
#     'oftid': 1611661325},
#    {'evt': 38,
#     'cl': '05:53',
#     'de': '[DAL] Pierson Turnover : Bad Pass (1 TO) Steal:Larkins (2 ST)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 5,
#     'opid': '201503',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 8,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 39,
#     'cl': '05:50',
#     'de': '[DAL] Phillips Foul: Personal (1 PF)',
#     'locX': -27,
#     'locY': 154,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '1627676',
#     'tid': 1611661321,
#     'pid': 101039,
#     'hs': 8,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 40,
#     'cl': '05:50',
#     'de': '[DAL] Paris Substitution replaced by Plaisance',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 201907,
#     'hs': 8,
#     'vs': 5,
#     'epid': '203849',
#     'oftid': 1611661325},
#    {'evt': 41,
#     'cl': '05:43',
#     'de': '[DAL] Pierson Foul: Personal (1 PF) (2 FTA)',
#     'locX': 20,
#     'locY': 31,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '201503',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 8,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 42,
#     'cl': '05:43',
#     'de': '[IND 9-5] Larkins Free Throw 1 of 2 (3 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 9,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 44,
#     'cl': '05:43',
#     'de': '[IND 10-5] Larkins Free Throw 2 of 2 (4 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 46,
#     'cl': '05:23',
#     'de': '[DAL] Sims Pullup Jump shot: Missed',
#     'locX': -13,
#     'locY': 165,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 79,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 47,
#     'cl': '05:23',
#     'de': '[IND] Wheeler Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 48,
#     'cl': '05:19',
#     'de': '[IND] Wheeler Turnover : Lost Ball (2 TO) Steal:Christmas (1 ST)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 2,
#     'etype': 5,
#     'opid': '202640',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 49,
#     'cl': '05:16',
#     'de': '[DAL] Plaisance Turnover : Bad Pass (1 TO)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 5,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 50,
#     'cl': '04:54',
#     'de': '[IND] Wheeler Jump Shot: Missed',
#     'locX': -26,
#     'locY': 85,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 51,
#     'cl': '04:53',
#     'de': '[IND] Larkins Rebound (Off:2 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 10,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 52,
#     'cl': '04:50',
#     'de': '[IND 12-5] Larkins Putback Layup Shot: Made (6 PTS)',
#     'locX': 7,
#     'locY': 7,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 72,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 12,
#     'vs': 5,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 53,
#     'cl': '04:32',
#     'de': '[DAL 7-12] Pierson Jump Shot: Made (4 PTS)',
#     'locX': 146,
#     'locY': 42,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 54,
#     'cl': '04:22',
#     'de': '[IND] Catchings 3pt Shot: Missed',
#     'locX': 37,
#     'locY': 238,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 55,
#     'cl': '04:21',
#     'de': '[DAL] Sims Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 56,
#     'cl': '04:16',
#     'de': '[DAL] Sims Turnover : Poss Lost Ball Turnover (1 TO)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 41,
#     'etype': 5,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 57,
#     'cl': '04:14',
#     'de': '[DAL] Plaisance Foul: Loose Ball (1 PF) (2 FTA)',
#     'locX': 129,
#     'locY': 15,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 3,
#     'etype': 6,
#     'opid': '204365',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 58,
#     'cl': '04:14',
#     'de': 'Timeout : Official',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 4,
#     'etype': 9,
#     'opid': '',
#     'tid': 0,
#     'pid': 0,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 60,
#     'cl': '04:14',
#     'de': '[DAL] Phillips Substitution replaced by Hooper',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 101039,
#     'hs': 12,
#     'vs': 7,
#     'epid': '203835',
#     'oftid': 1611661325},
#    {'evt': 61,
#     'cl': '04:14',
#     'de': '[DAL] Sims Substitution replaced by Kiesel',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 12,
#     'vs': 7,
#     'epid': '204331',
#     'oftid': 1611661325},
#    {'evt': 62,
#     'cl': '04:14',
#     'de': '[IND] Catchings Substitution replaced by Peters',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 100646,
#     'hs': 12,
#     'vs': 7,
#     'epid': '203016',
#     'oftid': 1611661325},
#    {'evt': 63,
#     'cl': '04:14',
#     'de': '[IND] Wheeler Free Throw 1 of 2 Missed',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 64,
#     'cl': '04:14',
#     'de': '[IND] Team Rebound',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 0,
#     'hs': 12,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 65,
#     'cl': '04:14',
#     'de': '[IND 13-7] Wheeler Free Throw 2 of 2 (3 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 13,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 67,
#     'cl': '03:54',
#     'de': '[DAL] Hooper Turnover : Bad Pass (1 TO) Steal:Wheeler (1 ST)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 5,
#     'opid': '204365',
#     'tid': 1611661321,
#     'pid': 203835,
#     'hs': 13,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 68,
#     'cl': '03:49',
#     'de': '[IND 15-7] Mitchell Layup Shot: Made (2 PTS) Assist: Johnson (2 AST)',
#     'locX': -7,
#     'locY': -8,
#     'opt1': 2,
#     'opt2': 1,
#     'mtype': 5,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 15,
#     'vs': 7,
#     'epid': '203018',
#     'oftid': 1611661325},
#    {'evt': 69,
#     'cl': '03:40',
#     'de': '[IND] Mitchell Foul: Personal (1 PF)',
#     'locX': 69,
#     'locY': 225,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '202640',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 15,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 70,
#     'cl': '03:40',
#     'de': '[IND] Wheeler Substitution replaced by Moseley',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 15,
#     'vs': 7,
#     'epid': '1627688',
#     'oftid': 1611661321},
#    {'evt': 73,
#     'cl': '03:40',
#     'de': '[IND] Larkins Foul: Personal (1 PF)',
#     'locX': 173,
#     'locY': 47,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '100888',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 15,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 74,
#     'cl': '03:33',
#     'de': '[DAL] Kiesel Jump Shot: Missed',
#     'locX': -76,
#     'locY': 167,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 204331,
#     'hs': 15,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 75,
#     'cl': '03:32',
#     'de': '[IND] Larkins Rebound (Off:2 Def:2)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 15,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 76,
#     'cl': '03:27',
#     'de': '[IND 17-7] Moseley Running Layup Shot: Made (2 PTS) Assist: Larkins (2 AST)',
#     'locX': 21,
#     'locY': -17,
#     'opt1': 2,
#     'opt2': 1,
#     'mtype': 41,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627688,
#     'hs': 17,
#     'vs': 7,
#     'epid': '201503',
#     'oftid': 1611661325},
#    {'evt': 77,
#     'cl': '03:08',
#     'de': '[DAL] Hooper 3pt Shot: Missed',
#     'locX': -232,
#     'locY': -22,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203835,
#     'hs': 17,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 78,
#     'cl': '03:08',
#     'de': '[DAL] Plaisance Rebound (Off:1 Def:0)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 17,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 79,
#     'cl': '03:05',
#     'de': '[DAL] Plaisance Reverse Layup Shot: Missed',
#     'locX': 20,
#     'locY': -6,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 44,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 17,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 80,
#     'cl': '03:05',
#     'de': '[IND] Team Rebound',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 0,
#     'hs': 17,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 81,
#     'cl': '03:05',
#     'de': '[IND] Johnson Substitution replaced by Lucas',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203018,
#     'hs': 17,
#     'vs': 7,
#     'epid': '203843',
#     'oftid': 1611661325},
#    {'evt': 82,
#     'cl': '02:55',
#     'de': '[DAL] Plaisance Foul: Personal (2 PF) (2 FTA)',
#     'locX': 37,
#     'locY': 145,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 6,
#     'opid': '1627676',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 17,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 83,
#     'cl': '02:55',
#     'de': '[IND 18-7] Mitchell Free Throw 1 of 2 (3 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 18,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 85,
#     'cl': '02:55',
#     'de': '[IND 19-7] Mitchell Free Throw 2 of 2 (4 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 19,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 87,
#     'cl': '02:52',
#     'de': '[DAL] Team Timeout : Regular',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 9,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 0,
#     'hs': 19,
#     'vs': 7,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 89,
#     'cl': '02:38',
#     'de': '[DAL 9-19] Pierson Driving Layup Shot: Made (6 PTS)',
#     'locX': 10,
#     'locY': -11,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 42,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 19,
#     'vs': 9,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 90,
#     'cl': '02:19',
#     'de': '[IND] Peters Jump Shot: Missed',
#     'locX': -127,
#     'locY': 3,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203016,
#     'hs': 19,
#     'vs': 9,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 91,
#     'cl': '02:18',
#     'de': '[IND] Larkins Rebound (Off:3 Def:2)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 19,
#     'vs': 9,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 92,
#     'cl': '02:11',
#     'de': '[IND 22-9] Mitchell 3pt Shot: Made (7 PTS) Assist: Larkins (3 AST)',
#     'locX': -105,
#     'locY': 227,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 22,
#     'vs': 9,
#     'epid': '201503',
#     'oftid': 1611661325},
#    {'evt': 93,
#     'cl': '01:51',
#     'de': '[DAL] Hooper Jump Shot: Missed',
#     'locX': -153,
#     'locY': -10,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203835,
#     'hs': 22,
#     'vs': 9,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 94,
#     'cl': '01:50',
#     'de': '[DAL] Plaisance Rebound (Off:2 Def:0)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 22,
#     'vs': 9,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 95,
#     'cl': '01:43',
#     'de': '[DAL 12-22] Hooper 3pt Shot: Made (3 PTS) Assist: Pierson (1 AST)',
#     'locX': -226,
#     'locY': -24,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203835,
#     'hs': 22,
#     'vs': 12,
#     'epid': '100888',
#     'oftid': 1611661321},
#    {'evt': 96,
#     'cl': '01:42',
#     'de': '[IND] Team Timeout : Regular',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 9,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 0,
#     'hs': 22,
#     'vs': 12,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 98,
#     'cl': '01:42',
#     'de': '[IND] Larkins Substitution replaced by Kizer',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 201503,
#     'hs': 22,
#     'vs': 12,
#     'epid': '203041',
#     'oftid': 1611661325},
#    {'evt': 99,
#     'cl': '01:42',
#     'de': '[IND] Mitchell Substitution replaced by Johnson',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627676,
#     'hs': 22,
#     'vs': 12,
#     'epid': '203018',
#     'oftid': 1611661325},
#    {'evt': 100,
#     'cl': '01:42',
#     'de': '[DAL] Pierson Substitution replaced by Sims',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 100888,
#     'hs': 22,
#     'vs': 12,
#     'epid': '203824',
#     'oftid': 1611661325},
#    {'evt': 101,
#     'cl': '01:42',
#     'de': '[DAL] Kiesel Substitution replaced by Powers',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 204331,
#     'hs': 22,
#     'vs': 12,
#     'epid': '1627672',
#     'oftid': 1611661325},
#    {'evt': 102,
#     'cl': '01:18',
#     'de': '[IND] Kizer Jump Shot: Missed',
#     'locX': 48,
#     'locY': 175,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203041,
#     'hs': 22,
#     'vs': 12,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 103,
#     'cl': '01:17',
#     'de': '[DAL] Christmas Rebound (Off:0 Def:2)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 202640,
#     'hs': 22,
#     'vs': 12,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 104,
#     'cl': '01:08',
#     'de': '[DAL 14-22] Plaisance Layup Shot: Made (2 PTS) Assist: Christmas (1 AST)',
#     'locX': 15,
#     'locY': -11,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 5,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 22,
#     'vs': 14,
#     'epid': '202640',
#     'oftid': 1611661321},
#    {'evt': 105,
#     'cl': '00:42.9',
#     'de': '[IND] Peters Turnaround Hook Shot: Missed',
#     'locX': 78,
#     'locY': 11,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 58,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203016,
#     'hs': 22,
#     'vs': 14,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 106,
#     'cl': '00:41.9',
#     'de': '[DAL] Sims Rebound (Off:0 Def:2)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 22,
#     'vs': 14,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 107,
#     'cl': '00:37.3',
#     'de': '[IND] Moseley Foul: Shooting (1 PF) (2 FTA)',
#     'locX': 34,
#     'locY': 77,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 2,
#     'etype': 6,
#     'opid': '203824',
#     'tid': 1611661325,
#     'pid': 1627688,
#     'hs': 22,
#     'vs': 14,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 108,
#     'cl': '00:37.3',
#     'de': '[DAL 15-22] Sims Free Throw 1 of 2 (1 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 11,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 22,
#     'vs': 15,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 110,
#     'cl': '00:37.3',
#     'de': '[IND] Moseley Substitution replaced by Wheeler',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 8,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 1627688,
#     'hs': 22,
#     'vs': 15,
#     'epid': '204365',
#     'oftid': 1611661321},
#    {'evt': 111,
#     'cl': '00:37.3',
#     'de': '[DAL 16-22] Sims Free Throw 2 of 2 (2 PTS)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 1,
#     'opt2': 0,
#     'mtype': 12,
#     'etype': 3,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203824,
#     'hs': 22,
#     'vs': 16,
#     'epid': '',
#     'oftid': 1611661321},
#    {'evt': 113,
#     'cl': '00:18.9',
#     'de': '[IND] Wheeler Jump Shot: Missed',
#     'locX': 110,
#     'locY': 165,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 204365,
#     'hs': 22,
#     'vs': 16,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 114,
#     'cl': '00:17.9',
#     'de': '[DAL] Powers Rebound (Off:0 Def:1)',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 1627672,
#     'hs': 22,
#     'vs': 16,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 115,
#     'cl': '00:05.1',
#     'de': '[DAL 19-22] Plaisance 3pt Shot: Made (5 PTS) Assist: Sims (2 AST)',
#     'locX': -59,
#     'locY': 233,
#     'opt1': 3,
#     'opt2': 0,
#     'mtype': 1,
#     'etype': 1,
#     'opid': '',
#     'tid': 1611661321,
#     'pid': 203849,
#     'hs': 22,
#     'vs': 19,
#     'epid': '203824',
#     'oftid': 1611661321},
#    {'evt': 116,
#     'cl': '00:00.0',
#     'de': '[IND] Johnson Running Jump Shot: Missed',
#     'locX': 2,
#     'locY': 118,
#     'opt1': 2,
#     'opt2': 0,
#     'mtype': 46,
#     'etype': 2,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 203018,
#     'hs': 22,
#     'vs': 19,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 117,
#     'cl': '00:00.0',
#     'de': '[IND] Team Rebound',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 4,
#     'opid': '',
#     'tid': 1611661325,
#     'pid': 0,
#     'hs': 22,
#     'vs': 19,
#     'epid': '',
#     'oftid': 1611661325},
#    {'evt': 118,
#     'cl': '00:00.0',
#     'de': 'End Period',
#     'locX': 0,
#     'locY': -80,
#     'opt1': 0,
#     'opt2': 0,
#     'mtype': 0,
#     'etype': 13,
#     'opid': '',
#     'tid': 0,
#     'pid': 0,
#     'hs': 22,
#     'vs': 19,
#     'epid': '',
#     'oftid': 1611661325}]}}

# %%
game_type = '1' #game_type = 1:preseason; 2:regular season; 3:all-star; 4:playoff
df = pandas.DataFrame() 

#loop through game numbers
for game_num in [str(x) for x in list(range(1,300))]:
    game_num = (4-len(game_num))*'0'+game_num #game_num = 1-n for preseason/regular season; series+0+number(1-5) for playoffs
    print(game_num)
    gid = '10'+game_type+year[2:4]+'0'+game_num
    quarter_num = '1'
    game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
    r = requests.get(game_url)
    game_data = json.loads(r.text)
    try:
        game_data = game_data['g']
        df = save_new_rows(df,game_data,'preseason')
    except:
        break
        
    #loop through quarters
    for quarter_num in [str(x) for x in list(range(2,10))]:
        game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
        r = requests.get(game_url)
        game_data = json.loads(r.text)
        try:
            game_data = game_data['g']
            df = save_new_rows(df,game_data,'preseason')
        except:
            break
preseason = df
# Out:
# 0001

# %%
game_type = '2' #game_type = 1:preseason; 2:regular season; 3:all-star; 4:playoff
df = pandas.DataFrame() 

#loop through game numbers
for game_num in [str(x) for x in list(range(1,300))]:
    game_num = (4-len(game_num))*'0'+game_num #game_num = 1-n for preseason/regular season; series+0+number(1-5) for playoffs
    print(game_num)
    gid = '10'+game_type+year[2:4]+'0'+game_num
    quarter_num = '1'
    game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
    r = requests.get(game_url)
    game_data = json.loads(r.text)
    try:
        game_data = game_data['g']
        df = save_new_rows(df,game_data,'regular season')
    except:
        break
    
    #loop through quarters
    for quarter_num in [str(x) for x in list(range(2,10))]:
        game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
        r = requests.get(game_url)
        game_data = json.loads(r.text)
        try:
            game_data = game_data['g']
            df = save_new_rows(df,game_data,'regular season')
        except:
            break
regular = df
# Out:
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# 0142
# 0143
# 0144
# 0145
# 0146
# 0147
# 0148
# 0149
# 0150
# 0151
# 0152
# 0153
# 0154
# 0155
# 0156
# 0157
# 0158
# 0159
# 0160
# 0161
# 0162
# 0163
# 0164
# 0165
# 0166
# 0167
# 0168
# 0169
# 0170
# 0171
# 0172
# 0173
# 0174
# 0175
# 0176
# 0177
# 0178
# 0179
# 0180
# 0181
# 0182
# 0183
# 0184
# 0185
# 0186
# 0187
# 0188
# 0189
# 0190
# 0191
# 0192
# 0193
# 0194
# 0195
# 0196
# 0197
# 0198
# 0199
# 0200
# 0201
# 0202
# 0203
# 0204
# 0205

# %%
game_type = '4' #game_type = 1:preseason; 2:regular season; 3:all-star; 4:playoff
df = pandas.DataFrame() 

#loop through game numbers
for round_num in [str(x) for x in list(range(1,5))]:
    for series_num in [str(x) for x in list(range(0,5))]:
        for game_num in [str(x) for x in list(range(1,6))]:
            game_num = '0'+round_num+series_num+game_num #game_num = 1-n for preseason/regular season; series+0+number(1-5) for playoffs
            gid = '10'+game_type+year[2:4]+'0'+game_num
            print(gid)
            quarter_num = '1'
            game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
            r = requests.get(game_url)
            game_data = json.loads(r.text)
            try:
                game_data = game_data['g']
                df = save_new_rows(df,game_data,'playoffs')
            except:
                continue
                
            #loop through quarters
            for quarter_num in [str(x) for x in list(range(2,10))]:
                game_url = 'https://data.wnba.com/data/5s/v2015/json/mobile_teams/wnba/'+year+'/scores/pbp/'+gid+'_'+quarter_num+'_pbp.json'
                r = requests.get(game_url)
                game_data = json.loads(r.text)
                try:
                    game_data = game_data['g']
                    df = save_new_rows(df,game_data,'playoffs')
                except:
                    break
playoffs = df
# Out:
# 1041600101
# 1041600102
# 1041600103
# 1041600104
# 1041600105
# 1041600111
# 1041600112
# 1041600113
# 1041600114
# 1041600115
# 1041600121
# 1041600122
# 1041600123
# 1041600124
# 1041600125
# 1041600131
# 1041600132
# 1041600133
# 1041600134
# 1041600135
# 1041600141
# 1041600142
# 1041600143
# 1041600144
# 1041600145
# 1041600201
# 1041600202
# 1041600203
# 1041600204
# 1041600205
# 1041600211
# 1041600212
# 1041600213
# 1041600214
# 1041600215
# 1041600221
# 1041600222
# 1041600223
# 1041600224
# 1041600225
# 1041600231
# 1041600232
# 1041600233
# 1041600234
# 1041600235
# 1041600241
# 1041600242
# 1041600243
# 1041600244
# 1041600245
# 1041600301
# 1041600302
# 1041600303
# 1041600304
# 1041600305
# 1041600311
# 1041600312
# 1041600313
# 1041600314
# 1041600315
# 1041600321
# 1041600322
# 1041600323
# 1041600324
# 1041600325
# 1041600331
# 1041600332
# 1041600333
# 1041600334
# 1041600335
# 1041600341
# 1041600342
# 1041600343
# 1041600344
# 1041600345
# 1041600401
# 1041600402
# 1041600403
# 1041600404
# 1041600405
# 1041600411
# 1041600412
# 1041600413
# 1041600414
# 1041600415
# 1041600421
# 1041600422
# 1041600423
# 1041600424
# 1041600425
# 1041600431
# 1041600432
# 1041600433
# 1041600434
# 1041600435
# 1041600441
# 1041600442
# 1041600443
# 1041600444
# 1041600445

# %%
df = preseason.append(regular)
df = df.append(playoffs)
df
# Out:
#     evt       cl                                                 de  locX  \
# 0     0    10:00                                       Start Period     0
# 1     1    10:00  Jump Ball Larkins vs Paris (Christmas gains po...     0
# 2     2    09:46  [DAL] Paris Turnover : Lost Ball (1 TO) Steal:...     0
# 3     3    09:38  [IND] Wheeler Turnover : Out of Bounds - Bad P...     0
# 4     4    09:26                   [DAL] Christmas 3pt Shot: Missed  -240
# ..  ...      ...                                                ...   ...
# 76  379  00:03.1               [LAS] Ogwumike Rebound (Off:6 Def:6)     0
# 77  380  00:02.1     [LAS 77-76] Ogwumike Layup Shot: Made (12 PTS)   -42
# 78  381  00:00.0                      [MIN] Whalen 3pt Shot: Missed   -10
# 79  382  00:00.0                                 [LAS] Team Rebound     0
# 80  384  00:00.0                                         End Period     0
#
#     locY  opt1  opt2  mtype  etype    opid  ...  vs    epid       oftid  \
# 0    -80     0     0      0     12          ...   0                   0
# 1    -80     0     0      0     10  201907  ...   0  202640  1611661321
# 2    -80     1     0      2      5  201503  ...   0          1611661321
# 3    -80     0     0     45      5          ...   0          1611661325
# 4     -6     3     0      1      2          ...   0          1611661321
# ..   ...   ...   ...    ...    ...     ...  ...  ..     ...         ...
# 76   -80     1     0      0      4          ...  75          1611661320
# 77     3     2     0      5      1          ...  77          1611661320
# 78   397     3     0      1      2          ...  77          1611661324
# 79   -80     0     0      0      4          ...  77          1611661324
# 80   -80     0     0      0     13          ...  77          1611661320
#
#            gid  year        gameType quarter       date homeTeam  awayTeam
# 0   1021600001  2016  regular season       1 2016-05-14      IND       DAL
# 1   1021600001  2016  regular season       1 2016-05-14      IND       DAL
# 2   1021600001  2016  regular season       1 2016-05-14      IND       DAL
# 3   1021600001  2016  regular season       1 2016-05-14      IND       DAL
# 4   1021600001  2016  regular season       1 2016-05-14      IND       DAL
# ..         ...   ...             ...     ...        ...      ...       ...
# 76  1041600405  2016        playoffs       4 2016-10-20      MIN       LAS
# 77  1041600405  2016        playoffs       4 2016-10-20      MIN       LAS
# 78  1041600405  2016        playoffs       4 2016-10-20      MIN       LAS
# 79  1041600405  2016        playoffs       4 2016-10-20      MIN       LAS
# 80  1041600405  2016        playoffs       4 2016-10-20      MIN       LAS
#
# [86299 rows x 23 columns]

# %%
df.to_csv('wnba-pbp-'+year+'.csv',index=False)
